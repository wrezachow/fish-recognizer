# %%
# !pip install -Uqq fastai

# %%
from fastai.vision.all import *

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/MasterCourse_Data_Science/Project_1
# Out:
# /content/drive/My Drive/MasterCourse_Data_Science/Project_1

# %%
version = 8
img_path = 'test_images'
model_path = f'models/fish-recognizer-v{version}.pkl'

# %%
model = load_learner(model_path)
# Out:
# /usr/local/lib/python3.12/dist-packages/fastai/learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")

# %%
img = "image5.jpeg"

# %%
img = Image.open(f'{img_path}/{img}')
img.to_thumb(256,256)
# Out:
# <PIL.Image.Image image mode=RGB size=256x90>

# %%
model.predict(f'{img_path}/{img}')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Hilsa Fish',
#  tensor(3),
#  tensor([1.0171e-02, 2.4869e-04, 7.5876e-02, 4.1824e-01, 8.4084e-02, 3.1978e-03,
#          8.1303e-04, 4.3079e-04, 2.3128e-04, 4.0671e-01]))

# %% [markdown]
# You can apply data augmentation transforms when creating your `ImageDataLoaders`. Here's an example using `RandomResizedCrop`, `Flip`, `BrightnessContrast`, and `HueSaturation`.

# %%
# # Assuming you have a path to your data
# # For example: path = Path('/content/drive/My Drive/MasterCourse_Data_Science/Project_1/fish_dataset')

# # Define your data augmentation transforms
# item_tfms = RandomResizedCrop(460, min_scale=0.75)
# batch_tfms = [*aug_transforms(mult=2, do_flip=True, pad_mode='reflection', max_lighting=0.1, max_zoom=1.1, max_warp=0.2, p_affine=0.75, p_lighting=0.75, xtra_tfms=None, size=None, mode='bilinear', align_corners=True, batch=False, min_scale=1.0), Normalize.from_stats(*imagenet_stats)]

# # Create DataLoaders with augmentation
# # dls = ImageDataLoaders.from_folder(path, valid_pct=0.2, item_tfms=item_tfms, batch_tfms=batch_tfms)

# # Display a batch with augmentations (uncomment and run after creating dls)
# # dls.show_batch(nrows=3, ncols=3)
